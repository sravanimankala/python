# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("sales.csv",delimiter=',')
data
# Out:
#      sale_id branch         city customer_type  gender  product_name  \
# 0          1      A     New York        Member    Male       Shampoo
# 1          2      B  Los Angeles        Normal  Female      Notebook
# 2          3      A     New York        Member  Female         Apple
# 3          4      A      Chicago        Normal    Male     Detergent
# 4          5      B  Los Angeles        Member  Female  Orange Juice
# ..       ...    ...          ...           ...     ...           ...
# 995      996      A     New York        Member  Female       Shampoo
# 996      997      A     New York        Member    Male     Detergent
# 997      998      A     New York        Member  Female       Shampoo
# 998      999      A     New York        Member  Female       Shampoo
# 999     1000      A     New York        Normal    Male  Orange Juice
#
#     product_category  unit_price  quantity   tax  total_price  reward_points
# ...

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sale_id           1000 non-null   int64
#  1   branch            1000 non-null   object
#  2   city              1000 non-null   object
#  3   customer_type     1000 non-null   object
#  4   gender            1000 non-null   object
#  5   product_name      1000 non-null   object
#  6   product_category  1000 non-null   object
#  7   unit_price        1000 non-null   float64
#  8   quantity          1000 non-null   int64
#  9   tax               1000 non-null   float64
#  10  total_price       1000 non-null   float64
#  11  reward_points     1000 non-null   int64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 93.9+ KB

# %%
data.head()
# Out:
#    sale_id branch         city customer_type  gender  product_name  \
# 0        1      A     New York        Member    Male       Shampoo
# 1        2      B  Los Angeles        Normal  Female      Notebook
# 2        3      A     New York        Member  Female         Apple
# 3        4      A      Chicago        Normal    Male     Detergent
# 4        5      B  Los Angeles        Member  Female  Orange Juice
#
#   product_category  unit_price  quantity   tax  total_price  reward_points
# 0    Personal Care        5.50         3  1.16        17.66              1
# 1       Stationery        2.75        10  1.93        29.43              0
# 2           Fruits        1.20        15  1.26        19.26              1
# 3        Household        7.80         5  2.73        41.73              0
# 4        Beverages        3.50         7  1.72        26.22              2

# %%
data.tail()
# Out:
#      sale_id branch      city customer_type  gender  product_name  \
# 995      996      A  New York        Member  Female       Shampoo
# 996      997      A  New York        Member    Male     Detergent
# 997      998      A  New York        Member  Female       Shampoo
# 998      999      A  New York        Member  Female       Shampoo
# 999     1000      A  New York        Normal    Male  Orange Juice
#
#     product_category  unit_price  quantity   tax  total_price  reward_points
# 995       Stationery        1.55        11  1.19        18.24              1
# 996    Personal Care        2.44         7  1.20        18.28              1
# 997       Stationery       17.92         2  2.51        38.35              3
# 998        Beverages       17.41         4  4.87        74.51              7
# 999       Stationery        4.11         4  1.15        17.59              0

# %%
data.describe()
# Out:
#            sale_id   unit_price     quantity          tax  total_price  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000    10.836110    10.337000     7.758010   118.583900
# std     288.819436     5.775924     6.029908     6.538066    99.936441
# min       1.000000     1.020000     1.000000     0.080000     1.210000
# 25%     250.750000     5.867500     5.000000     2.510000    38.380000
# 50%     500.500000    10.615000    10.000000     5.870000    89.705000
# 75%     750.250000    15.882500    16.000000    11.522500   176.072500
# max    1000.000000    20.980000    20.000000    28.390000   433.990000
#
#        reward_points
# count    1000.000000
# mean        6.057000
# std         9.350464
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        10.000000
# max        43.000000

# %%
data.loc[10:100]
# Out:
#      sale_id branch         city customer_type  gender  product_name  \
# 10        11      A      Chicago        Normal    Male     Detergent
# 11        12      B  Los Angeles        Member    Male  Orange Juice
# 12        13      A     New York        Normal  Female  Orange Juice
# 13        14      B  Los Angeles        Member  Female         Apple
# 14        15      B  Los Angeles        Normal  Female         Apple
# ..       ...    ...          ...           ...     ...           ...
# 96        97      B  Los Angeles        Member    Male  Orange Juice
# 97        98      B  Los Angeles        Normal    Male      Notebook
# 98        99      A     New York        Normal    Male     Detergent
# 99       100      A      Chicago        Member    Male      Notebook
# 100      101      B  Los Angeles        Member    Male  Orange Juice
#
#     product_category  unit_price  quantity    tax  total_price  reward_points
# ...

# %%
data.iloc[11:20]
# Out:
#     sale_id branch         city customer_type  gender  product_name  \
# 11       12      B  Los Angeles        Member    Male  Orange Juice
# 12       13      A     New York        Normal  Female  Orange Juice
# 13       14      B  Los Angeles        Member  Female         Apple
# 14       15      B  Los Angeles        Normal  Female         Apple
# 15       16      B  Los Angeles        Normal    Male      Notebook
# 16       17      B  Los Angeles        Member  Female         Apple
# 17       18      B  Los Angeles        Normal    Male      Notebook
# 18       19      A     New York        Member    Male         Apple
# 19       20      A      Chicago        Normal    Male     Detergent
#
#    product_category  unit_price  quantity    tax  total_price  reward_points
# 11        Household        6.89        12   5.79        88.47              8
# 12        Household        3.29         4   0.92        14.08              0
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull()
# Out:
#      sale_id  branch   city  customer_type  gender  product_name  \
# 0      False   False  False          False   False         False
# 1      False   False  False          False   False         False
# 2      False   False  False          False   False         False
# 3      False   False  False          False   False         False
# 4      False   False  False          False   False         False
# ..       ...     ...    ...            ...     ...           ...
# 995    False   False  False          False   False         False
# 996    False   False  False          False   False         False
# 997    False   False  False          False   False         False
# 998    False   False  False          False   False         False
# 999    False   False  False          False   False         False
#
#      product_category  unit_price  quantity    tax  total_price  reward_points
# 0               False       False     False  False        False          False
# ...

# %%
data.isnull().sum()
# Out:
# sale_id             0
# branch              0
# city                0
# customer_type       0
# gender              0
# product_name        0
# product_category    0
# unit_price          0
# quantity            0
# tax                 0
# total_price         0
# reward_points       0
# dtype: int64

# %%
data.iloc[:20:]
# Out:
#     sale_id branch         city customer_type  gender  product_name  \
# 0         1      A     New York        Member    Male       Shampoo
# 1         2      B  Los Angeles        Normal  Female      Notebook
# 2         3      A     New York        Member  Female         Apple
# 3         4      A      Chicago        Normal    Male     Detergent
# 4         5      B  Los Angeles        Member  Female  Orange Juice
# 5         6      A      Chicago        Normal    Male       Shampoo
# 6         7      A      Chicago        Normal    Male       Shampoo
# 7         8      B  Los Angeles        Normal  Female       Shampoo
# 8         9      A      Chicago        Member  Female         Apple
# 9        10      B  Los Angeles        Member    Male       Shampoo
# 10       11      A      Chicago        Normal    Male     Detergent
# 11       12      B  Los Angeles        Member    Male  Orange Juice
# 12       13      A     New York        Normal  Female  Orange Juice
# ...

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
data.transpose()
# Out:
#                             0            1         2          3    \
# sale_id                       1            2         3          4
# branch                        A            B         A          A
# city                   New York  Los Angeles  New York    Chicago
# customer_type            Member       Normal    Member     Normal
# gender                     Male       Female    Female       Male
# product_name            Shampoo     Notebook     Apple  Detergent
# product_category  Personal Care   Stationery    Fruits  Household
# unit_price                  5.5         2.75       1.2        7.8
# quantity                      3           10        15          5
# tax                        1.16         1.93      1.26       2.73
# total_price               17.66        29.43     19.26      41.73
# reward_points                 1            0         1          0
#
#                            4           5              6            7    \
# ...

# %%
data.dropna()
# Out:
#      sale_id branch         city customer_type  gender  product_name  \
# 0          1      A     New York        Member    Male       Shampoo
# 1          2      B  Los Angeles        Normal  Female      Notebook
# 2          3      A     New York        Member  Female         Apple
# 3          4      A      Chicago        Normal    Male     Detergent
# 4          5      B  Los Angeles        Member  Female  Orange Juice
# ..       ...    ...          ...           ...     ...           ...
# 995      996      A     New York        Member  Female       Shampoo
# 996      997      A     New York        Member    Male     Detergent
# 997      998      A     New York        Member  Female       Shampoo
# 998      999      A     New York        Member  Female       Shampoo
# 999     1000      A     New York        Normal    Male  Orange Juice
#
#     product_category  unit_price  quantity   tax  total_price  reward_points
# ...

# %%
data.fillna(value='abc')
# Out:
#      sale_id branch         city customer_type  gender  product_name  \
# 0          1      A     New York        Member    Male       Shampoo
# 1          2      B  Los Angeles        Normal  Female      Notebook
# 2          3      A     New York        Member  Female         Apple
# 3          4      A      Chicago        Normal    Male     Detergent
# 4          5      B  Los Angeles        Member  Female  Orange Juice
# ..       ...    ...          ...           ...     ...           ...
# 995      996      A     New York        Member  Female       Shampoo
# 996      997      A     New York        Member    Male     Detergent
# 997      998      A     New York        Member  Female       Shampoo
# 998      999      A     New York        Member  Female       Shampoo
# 999     1000      A     New York        Normal    Male  Orange Juice
#
#     product_category  unit_price  quantity   tax  total_price  reward_points
# ...

# %%
data.groupby(['product_name']).sum()
# Out:
#               sale_id                                             branch  \
# product_name
# Apple           94679  AABBBAAAAAAAAAAAAAAAAAAAABBAABABAAAAAABABBBBAA...
# Detergent       93448  AAABAAAABBAAAAAAAAAABAABAAABABABAAAAAABAAABAAA...
# Notebook        93348  BBBBBBAAABAAAABBAABBBAABAABAAAAAAABAABAABAABAB...
# Orange Juice   104244  BBABAABABAAAAAABAABBAABBBABBAAABAAAABAABBAAABA...
# Shampoo        114780  AABBBABABBAAABAAABAAAAABAAAABAAAAABBBAABABAAAB...
#
#                                                            city  \
# product_name
# Apple         New YorkChicagoLos AngelesLos AngelesLos Angel...
# Detergent     ChicagoChicagoChicagoLos AngelesNew YorkNew Yo...
# Notebook      Los AngelesLos AngelesLos AngelesLos AngelesLo...
# Orange Juice  Los AngelesLos AngelesNew YorkLos AngelesChica...
# Shampoo       ChicagoChicagoLos AngelesLos AngelesLos Angele...
#
#                                                   customer_type  \
# product_name
# ...

# %%
data1=pd.get_dummies(data['city'],dtype=int)
data1
# Out:
#      Chicago  Los Angeles  New York
# 1          0            1         0
# 2          0            0         1
# 3          1            0         0
# 4          0            1         0
# 5          1            0         0
# ..       ...          ...       ...
# 995        0            0         1
# 996        0            0         1
# 997        0            0         1
# 998        0            0         1
# 999        0            0         1
#
# [999 rows x 3 columns]
